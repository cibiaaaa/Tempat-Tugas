# %% [markdown]
# <a href="https://colab.research.google.com/github/cibiaaaa/Tempat-Tugas/blob/main/tugas_algoritma_xpplg_raffida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas catatan rafida

# %% [markdown]
# ![tugas ringkasan algoritma.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![tugas latihan algoritma.jpg](data:image/jpeg;base64,...)
